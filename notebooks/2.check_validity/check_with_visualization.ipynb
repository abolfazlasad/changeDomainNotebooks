# %% [markdown]
# use data from
#  - notebooks/1.change_format/output/data
#  - amass_30fps_text.pt from motionClip
#
#  as input for checking validity of my change

# %%
# !mkdir input
# !cp -r ../1.change_format/output/data ./input/

# %%
import joblib
import numpy as np

# %%
data = joblib.load("./input/amass_30fps_test.pt")
data["joints3d"][0].shape

# %%
index_to_joint = {
    0: 'pelvis',
     1: 'left_hip',
     2: 'right_hip',
     3: 'spine1',
     4: 'left_knee',
     5: 'right_knee',
     6: 'spine2',
     7: 'left_ankle',
     8: 'right_ankle',
     9: 'spine3',
    10: 'left_foot',
    11: 'right_foot',
    12: 'neck',
    13: 'left_collar',
    14: 'right_collar',
    15: 'head',
    16: 'left_shoulder',
    17: 'right_shoulder',
    18: 'left_elbow',
    19: 'right_elbow',
    20: 'left_wrist',
    21: 'right_wrist',
    22: 'left_index1',
    23: 'left_index2',
    24: 'left_index3',
    25: 'left_middle1',
    26: 'left_middle2',
    27: 'left_middle3',
    28: 'left_pinky1',
    29: 'left_pinky2',
    30: 'left_pinky3',
    31: 'left_ring1',
    32: 'left_ring2',
    33: 'left_ring3',
    34: 'left_thumb1',
    35: 'left_thumb2',
    36: 'left_thumb3',
    37: 'right_index1',
    38: 'right_index2',
    39: 'right_index3',
    40: 'right_middle1',
    41: 'right_middle2',
    42: 'right_middle3',
    43: 'right_pinky1',
    44: 'right_pinky2',
    45: 'right_pinky3',
    46: 'right_ring1',
    47: 'right_ring2',
    48: 'right_ring3',
    49: 'right_thumb1',
    50: 'right_thumb2',
    51: 'right_thumb3'
    }

# %%
joints = [ 8, 1, 2, 3, 4, 5, 6, 7, 0, 9, 10, 11, 12, 13, 14, 21, 24, 38 ]

joints = [index_to_joint[j] for j in joints]
print(joints)
joints_to_index = {j:i for i, j in enumerate(joints)}
print(joints_to_index)

# %%
data_index = 0
input_data = data["joints3d"][data_index]

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation

# Create a 3D plot
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

def update(frame_idx):
    ax.cla()

    ax.set_xlim(-1, 1)
    ax.set_ylim(-1, 1)
    ax.set_zlim(-1, 1)

    points = input_data[frame_idx]
    x = points[:, 0]
    y = points[:, 1]
    z = points[:, 2]
    ax.scatter(x, y, z, c='b', marker='o')  # Scatter plot for the points

    for v in [
        ('pelvis', 'left_hip'), ('pelvis', 'right_hip'),
        ('left_hip', 'left_knee'), ('right_hip', 'right_knee'),
        ('left_knee', 'left_ankle'), ('right_knee', 'right_ankle'),
        ('left_ankle', 'left_foot'), ('right_ankle', 'right_foot'),
        ('pelvis', 'spine1'),
        ('spine1', 'spine2'),
        ('spine2', 'spine3'),
        ('spine3', 'neck'),
        ('left_collar', 'right_collar'),
        ('right_collar', 'right_wrist'),
        ('right_wrist', 'right_index2'),
        ('left_collar', 'left_index3')
    ]:
        vec = [joints_to_index[j] for j in v]

        ax.plot(xs=x[vec], ys=y[vec], zs=z[vec], c='r', linestyle='-', marker='o')  # Line plot connecting the points


    # Set labels for the axes
    ax.set_xlabel('X Axis')
    ax.set_ylabel('Y Axis')
    ax.set_zlabel('Z Axis')

    # Set the title
    ax.set_title(data["text_raw_labels"][data_index][frame_idx])

    # Show the plot
    plt.draw()# 


fps = 30
ani = FuncAnimation(fig, update, frames=len(input_data), interval=1000/fps, repeat=False)

ani.save('amass_sample_data.mp4', writer='ffmpeg', fps=fps, dpi=80)

# %%
# data is 120 fps and here is 30 fps
file = "depressed_12_000.npy"
file = "angry_12_000.npy"
file = "childlike_12_000.npy"
input_data = np.load("./input/data/" + file)[::4]

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation

# Create a 3D plot
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

def update(frame_idx):
    ax.cla()

    ax.set_xlim(-10, 25)
    ax.set_ylim(-10, 25)
    ax.set_zlim(-10, 25)

    points = input_data[frame_idx]
    x = points[:, 0]
    y = points[:, 1]
    z = points[:, 2]
    ax.scatter(x, y, z, c='b', marker='o')  # Scatter plot for the points

    for v in [
        ('pelvis', 'left_hip'), ('pelvis', 'right_hip'),
        ('left_hip', 'left_knee'), ('right_hip', 'right_knee'),
        ('left_knee', 'left_ankle'), ('right_knee', 'right_ankle'),
        ('left_ankle', 'left_foot'), ('right_ankle', 'right_foot'),
        ('pelvis', 'spine1'),
        ('spine1', 'spine2'),
        ('spine2', 'spine3'),
        ('spine3', 'neck'),
        ('left_collar', 'right_collar'),
        ('right_collar', 'right_wrist'),
        ('right_wrist', 'right_index2'),
        ('left_collar', 'left_index3')
    ]:
        vec = [joints_to_index[j] for j in v]

        ax.plot(xs=x[vec], ys=y[vec], zs=z[vec], c='r', linestyle='-', marker='o')  # Line plot connecting the points


    # Set labels for the axes
    ax.set_xlabel('X Axis')
    ax.set_ylabel('Y Axis')
    ax.set_zlabel('Z Axis')

    # Set the title
    # ax.set_title(data["text_raw_labels"][data_index][frame_idx])

    # Show the plot
    plt.draw()# 


fps = 30
ani = FuncAnimation(fig, update, frames=len(input_data), interval=1000/fps, repeat=False)

ani.save('changed_data_%s.mp4' % file[:-4], writer='ffmpeg', fps=fps, dpi=80)
